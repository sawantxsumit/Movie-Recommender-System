# %%
from movie_recommeder import recommend_top10 , fetch_poster
# Out:
# Models loaded successfully

# %%
movies, posters = recommend_top10("Batman")
print(movies)
print(posters)
# Out:
# ['Batman & Robin', 'Batman Returns', 'The Dark Knight Rises', 'Batman Begins', 'Batman Forever', 'The Dark Knight', 'Batman v Superman: Dawn of Justice', 'Superman', 'Spider-Man 2', 'Chill Factor']
# ['https://image.tmdb.org/t/p/w500//i7hEUpDuMN2LOrCEifFyGSHZQSY.jpg', 'https://image.tmdb.org/t/p/w500//jKBjeXM7iBBV9UkUcOXx3m7FSHY.jpg', 'https://image.tmdb.org/t/p/w500//hr0L2aueqlP2BYUblTTjmtn0hw4.jpg', 'https://image.tmdb.org/t/p/w500//sPX89Td70IDDjVr85jdSBb4rWGr.jpg', 'https://image.tmdb.org/t/p/w500//i0fJS8M5UKoETjjJ0zwUiKaR8tr.jpg', 'https://image.tmdb.org/t/p/w500//qJ2tW6WMUDux911r6m7haRef0WH.jpg', 'https://image.tmdb.org/t/p/w500//5UsK3grJvtQrtzEgqNlDljJW96w.jpg', 'https://image.tmdb.org/t/p/w500//d7px1FQxW4tngdACVRsCSaZq0Xl.jpg', 'https://image.tmdb.org/t/p/w500//aGuvNAaaZuWXYQQ6N2v7DeuP6mB.jpg', 'https://image.tmdb.org/t/p/w500//t8Qn1iKnvVOttEqaj6hz9tKGBjD.jpg']
